# %%
# Inicializar las variables que almacenarán los totales y contar la cantidad de estudiantes
total_general = 0
total_practico = 0
total_teorico = 0
total_hombres = 0
total_mujeres = 0
cantidad_estudiantes = 0
nota_minima_hombres = float('inf')
nota_minima_mujeres = float('inf')
nota_maxima_hombres = float('-inf')
nota_maxima_mujeres = float('-inf')

# pedir la cantidad de estudiantes
cantidad_estudiantes = int(input("Ingrese la cantidad de estudiantes: "))

# ciclo para pedir las notas de cada estudiante
for i in range(cantidad_estudiantes):
    # Pedir los datos del estudiante
    nombre = input("Ingrese el nombre del estudiante: ")
    nota_practico = float(input("Ingrese la nota del parcial práctico: "))
    nota_teorico = float(input("Ingrese la nota del parcial teórico: "))
    sexo = input("Ingrese el sexo del estudiante (M/F): ")
    
    # Calcular la nota definitiva
    nota_definitiva = (nota_practico + nota_teorico) / 2
    
    # Sumar las notas a los totales generales
    total_general += nota_definitiva
    total_practico += nota_practico
    total_teorico += nota_teorico
    
    # Sumar las notas a los totales de hombres o mujeres
    if sexo == "M":
        total_hombres += nota_definitiva
        if nota_definitiva < nota_minima_hombres:
            nota_minima_hombres = nota_definitiva
        if nota_definitiva > nota_maxima_hombres:
            nota_maxima_hombres = nota_definitiva
    else:
        total_mujeres += nota_definitiva
        if nota_definitiva < nota_minima_mujeres:
            nota_minima_mujeres = nota_definitiva
        if nota_definitiva > nota_maxima_mujeres:
            nota_maxima_mujeres = nota_definitiva

# Calcular los promedios
promedio_general = total_general / cantidad_estudiantes
v_proNotExateo= v_sumaNotExateo / v_canEst
promedio_practico = total_practico / cantidad_estudiantes
# Out:
# Ingrese la cantidad de estudiantes: 2
# Ingrese el nombre del estudiante: ximena
# Ingrese la nota del parcial práctico: 5
# Ingrese la nota del parcial teórico: 5
# Ingrese el sexo del estudiante (M/F): F
# Ingrese el nombre del estudiante: Katherin
# Ingrese la nota del parcial práctico: 4
# Ingrese la nota del parcial teórico: 4
# Ingrese el sexo del estudiante (M/F): F
