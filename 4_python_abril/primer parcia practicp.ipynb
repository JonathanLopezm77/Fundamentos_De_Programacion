# %%
#Analicis del primer parcial de FP

v_canEst=5
c_valexateo = 0.40
c_valExaPra = 0.60
v_defPriPar = 0.0
v_conCic= 1
v_sumaNotExaPra = 0.0
v_proNotExaPra= 0.0
v_sumaNotExateo = 0.0
v_proNotExateo = 0.0
v_sumNotPriPar = 0.0
v_proNotPriPar = 0.0
v_ASDEM= 0
v_ACEM=0
v_ASDEH= 0
v_ACEH=0
c_NMAXG = 0
c_NMING = 5.1
c_NMAXM = 0
c_NMINM= 5.1
# Leer cantidad de estiudiantes
v_canEst= int(input("Digite cantidad de estudaintes :"))


for v_conCic = 1 in range (v_canEst):
#Captua de los datos
    v_nomEst= input("Nombre estudiante : ")# Lectura del nombre
    v_genEst=input("Genero de estudiante : ")
    v_notExaTeo= float(input("Digite la nota del examne teorico: "))
    v_notExaPra= float(input("Digite la nota del examne teorico: "))
#Calculo de la nota del primer parcial por estudiante
    v_notDefPriPar = (v_notExaTeo*c_valexateo ) + (v_notExaPra * c_valExaPra)
    print("Su nota del primer parcial es : ", v_notDefPriPar)
#Acumulador nota definitiva estudiantes
    v_ASDE=v_ASDE + v_notDefPriPar
#condicional nota maxima general
    if v_notDefPriPar > c_NMAXG
    C_NMAXG = v_notDefPriPar
#condicional nota miniama general
  if v_notDefPriPar > c_NMING
    c_NMING = v_notDefPriPar
#condicional mujeres 
    if v_genEst == "F"
      v_ASDEM= ASDEM + v_notDefPriPar
      v_ACEM== ACEM + 1
#condicional nota maxima mujeres
            if v_notDefPriPar > c_NMAXM
            c_NMAXM = v_notDefPriPar
#condicional nota miniama mujeres
             if v_notDefPriPar > c_NMINM
              c_NMINM = v_notDefPriPar
#Condicional hombres
  elif 
      v_ASDEH= ASDEH + v_notDefPriPar
      v_ACEH== ACEH + 1
#condicional nota maxima hombres
            if v_notDefPriPar > c_NMAXH
            c_NMAXH = v_notDefPriPar
#condicional nota miniama hombres
             if v_notDefPriPar > c_NMINH
              c_NMINH = v_notDefPriPar
#Calcular la suma de las notas del examen teorico
    v_sumaNotExateo= v_sumaNotExateo + v_notExaTeo

#Calcular la suma de las notas de los estudiantes para calcular el promedio
    v_sumNotaPriPar = v_sumNotaPriPar + v_notDefPriPar

#Calcular promedio del grupo de las notas del examne teorico
v_proNotExateo= v_sumaNotExateo / v_canEst
print("EL promedio de grupo de las notas del examen teorico es : ", v_proNotExateo )

#Calcular promedio del grupo de las notas dek examne practico
v_proNotExaPra= v_sumaNotExaPra / v_canEst
print("EL promedio de grupo de las notas del examen practico es : ", v_proNotExaPra )

# Calcular promedio del grupo de las notas del primer parcial
v_proNotPriPar= v_sumNotaPriPar / v_canEst
print("El promedio de grupo del primper parcial es : ", v_proNotPriPar) 

#Calcular promedio de las notas de los hombre
